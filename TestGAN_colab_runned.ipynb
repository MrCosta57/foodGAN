# %%
# %pip install --quiet lightning

from google.colab import drive
drive.mount('/content/drive')
lib_path=r"/content/drive/MyDrive/Colab Notebooks/ML/ML_project/"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.7/596.7 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 729.2/729.2 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.4/722.4 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import sys
sys.path.append(lib_path)
from model import GAN
from dataset import Custom_Food101
import matplotlib.pyplot as plt

# %%
dataset=Custom_Food101()
dataset.prepare_data()
data_loader=dataset.get_dataloader()
# Out:
# Extract dataset in  /tmp/tmpwgj9cexo
# Extraction done!

# %%
gan=GAN()
gan.training_loop(data_loader, 15, debug_mode=True, debug_grad=False)
# Out:
# Training started!
# End fabric setup
#  32%|███▏      | 250/790 [04:02<07:23,  1.22it/s]
# Epoch [1/15] Batch 250/790                 Loss D: -122.1800, loss G: 106.0211
#  63%|██████▎   | 500/790 [08:06<03:55,  1.23it/s]
# Epoch [1/15] Batch 500/790                 Loss D: -102.7904, loss G: 117.2161
#  95%|█████████▍| 750/790 [12:09<00:35,  1.13it/s]
# Epoch [1/15] Batch 750/790                 Loss D: -80.9446, loss G: 116.0779
# ...
#  32%|███▏      | 250/790 [03:55<09:58,  1.11s/it]
# Epoch [2/15] Batch 250/790                 Loss D: -61.6785, loss G: 118.9040
#  63%|██████▎   | 500/790 [07:46<04:12,  1.15it/s]
# Epoch [2/15] Batch 500/790                 Loss D: -47.1882, loss G: 119.9125
#  95%|█████████▍| 750/790 [11:42<00:44,  1.10s/it]
# Epoch [2/15] Batch 750/790                 Loss D: -40.6892, loss G: 117.1311
# ...
#  32%|███▏      | 250/790 [03:44<09:56,  1.10s/it]
# Epoch [3/15] Batch 250/790                 Loss D: -36.8389, loss G: 110.9628
# ...

# %%
print("Donuts generation...")
grid=gan.generate(31)
plt.axis("off")
plt.imshow(grid)
plt.show()
# Out:
# Donuts generation...

# %%
print("Hot dogs generation...")
grid=gan.generate(55)
plt.axis("off")
plt.imshow(grid)
plt.show()
# Out:
# Hot dogs generation...

# %%
print("Apple pies generation...")
grid=gan.generate(0)
plt.axis("off")
plt.imshow(grid)
plt.show()
# Out:
# Apple pies generation...

# %%
# %load_ext tensorboard
# %tensorboard --logdir "/content/drive/MyDrive/Colab Notebooks/ML/ML_project/logs/food_gan"
